# %% [markdown]
# ## Pandas Tutorial On Stock Price Analysis
# **This tutorial will cover to retrieve stock price from yahoo finance using pandas data reader.**
# The analysis of stock is done by ploting its high,low,close,colume values in table and chart.
# Charts are of two types:
#    1. Line Chart
#    2. Bar Chart
#
# If you don't know what is stock then first watch this video to gain understanding on fundamentals of stocks and investing.

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/A7sLx1Rwevo" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/A7sLx1Rwevo" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
import pandas_datareader.data as web
df = web.DataReader("F", 'yahoo', '2016/1/1', '2017/1/1')
df.head()
# Out:
#              High    Low   Open  Close      Volume  Adj Close
# Date
# 2015-12-31  14.16  14.04  14.14  14.09  19881000.0  10.338695
# 2016-01-04  14.00  13.75  13.87  13.97  38618500.0  10.250646
# 2016-01-05  14.00  13.51  13.97  13.72  50267500.0  10.067203
# 2016-01-06  13.56  13.05  13.56  13.11  61285500.0   9.619610
# 2016-01-07  13.04  12.60  12.90  12.70  57846700.0   9.318768

# %%
# %matplotlib inline
df.plot(y="Close",color="Green")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.plot.bar(y="Volume")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# %time for i in range(100000):i*i
# Out:
# CPU times: user 14.9 ms, sys: 295 µs, total: 15.2 ms
# Wall time: 15.1 ms

# %%
# %system pwd
# Out:
# ['/Users/shahmdmesbahulislam/Documents/code/Data_Science_nd_ML']

# %%
# %system ls
# Out:
# ['python_pandas_notebook.ipynb']

# %%
# !ls
# Out:
# python_pandas_notebook.ipynb

# %%
# !pwd
# Out:
# /Users/shahmdmesbahulislam/Documents/code/Data_Science_nd_ML
