# %%
import pandas as pd
df = pd.read_csv("/Users/shahmdmesbahulislam/Documents/code/Data_Science_nd_ML/Pandas/Pandas_Tutorial_7_Groupby_CSV.csv")
df
# Out:
#        day      city  temperature  windspeed   event
# 0   1/1/17  new york           32          6    Rain
# 1   1/2/17  new york           36          7   Sunny
# 2   1/3/17  new york           28         12    Snow
# 3   1/4/17  new york           33          7   Sunny
# 4   1/1/17    mumbai           90          5   Sunny
# 5   1/2/17    mumbai           85         12     Fog
# 6   1/3/17    mumbai           87         15     Fog
# 7   1/4/17    mumbai           92          5    Rain
# 8   1/1/17     paris           45         20   Sunny
# 9   1/2/17     paris           50         13  Cloudy
# 10  1/3/17     paris           54          8  Cloudy
# 11  1/4/17     paris           42         10  Cloudy

# %%
g = df.groupby('city')
g

# %%
for city,city_df in g:
    print(city)
    print(city_df)
# Out:
# mumbai
#       day    city  temperature  windspeed  event
# 4  1/1/17  mumbai           90          5  Sunny
# 5  1/2/17  mumbai           85         12    Fog
# 6  1/3/17  mumbai           87         15    Fog
# 7  1/4/17  mumbai           92          5   Rain
# new york
#       day      city  temperature  windspeed  event
# 0  1/1/17  new york           32          6   Rain
# 1  1/2/17  new york           36          7  Sunny
# 2  1/3/17  new york           28         12   Snow
# 3  1/4/17  new york           33          7  Sunny
# paris
#        day   city  temperature  windspeed   event
# 8   1/1/17  paris           45         20   Sunny
# 9   1/2/17  paris           50         13  Cloudy
# 10  1/3/17  paris           54          8  Cloudy
# 11  1/4/17  paris           42         10  Cloudy

# %%
g.get_group('mumbai')
# Out:
#       day    city  temperature  windspeed  event
# 4  1/1/17  mumbai           90          5  Sunny
# 5  1/2/17  mumbai           85         12    Fog
# 6  1/3/17  mumbai           87         15    Fog
# 7  1/4/17  mumbai           92          5   Rain

# %%
g.max()
# Out:
#              day  temperature  windspeed  event
# city
# mumbai    1/4/17           92         15  Sunny
# new york  1/4/17           36         12  Sunny
# paris     1/4/17           54         20  Sunny

# %%
g.mean()
# Out:
# /var/folders/w3/vd31m_lx5f54537qkrrjg9dm0000gn/T/ipykernel_45529/2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
g.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
# %matplotlib inline
g.plot()
# Out:
# city
# mumbai      AxesSubplot(0.125,0.11;0.775x0.77)
# new york    AxesSubplot(0.125,0.11;0.775x0.77)
# paris       AxesSubplot(0.125,0.11;0.775x0.77)
# dtype: object
